# %%
from E_Coli_Project import Simulation

# %%
Ns = [10, 100, 1000]

# %%
#Gaussian
for N in Ns:
    sim = Simulation(N,  "gaussian")
    x, y = sim.run_simulation(1000, hist = True)
    distance = sim.get_histogram(x, y)
